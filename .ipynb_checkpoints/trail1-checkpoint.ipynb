# %%
import pandas as pd

dataset = pd.read_csv('combined.csv',low_memory=False)
dataset.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16208\1464348534.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   dataset = pd.read_csv('combined.csv',error_bad_lines=False)
# C:\Users\user\AppData\Local\Temp\ipykernel_16208\1464348534.py:3: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv('combined.csv',error_bad_lines=False)
#    Unnamed: 0  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  \
# 0           0        2      6             2            3                AA
# 1           1        2      6             2            3                AA
# 2           2        2      6             2            3                AA
# 3           3        2      6             2            3                AA
# 4           4        2      6             2            3                AA
#
# ...

# %%
dataset = dataset.drop(['Unnamed: 0',
                        'ORIGIN_AIRPORT_ID',  
                        'DEST_AIRPORT_ID',
                        'DEST_CITY_MARKET_ID',
                        'Origin_id','Origin_station_name',
                        'Unnamed: 27',
                        'Dest_id',
                        'station_name'
                       ],axis=1)

# %%
dataset['TOTAL_DELAY'] = dataset['DEP_DELAY_NEW']+dataset['ARR_DELAY_NEW']
dataset = dataset.drop(['DEP_DELAY_NEW',
                        'ARR_DELAY_NEW'
                       ],axis=1)

# %%
dataset=dataset.drop(['Origin_weather_type','Dest_weather_type'],axis=1)

# %%
dataset.to_csv('combined_filtered.csv')

# %%
datasetx = dataset

# %%
datasetx.head()
# Out:
#    QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST  \
# 0        2      6             2            3                AA    CLT  MCI
# 1        2      6             2            3                AA    CLT  PHX
# 2        2      6             2            3                AA    CLT  CHS
# 3        2      6             2            3                AA    CLT  PHL
# 4        2      6             2            3                AA    CLT  MCO
#
#    CRS_DEP_TIME  DEP_DEL15  DEP_DELAY_GROUP  ... Dest_pressure_avg_stn  \
# 0          1850        0.0              0.0  ...                 28.92
# 1           714        0.0             -1.0  ...                 28.59
# 2          2255        0.0             -1.0  ...                 29.98
# 3          1105        0.0             -1.0  ...                 29.93
# 4           905        0.0             -1.0  ...                 29.91
#
#    Dest_pressure_avg_SL  Dest_?1  Dest_?2 Dest_wind  Dest_peak_speed  \
# ...

# %%
datasetx.to_csv('dre.csv')

# %%
import pandas as pd

datasetx = pd.read_csv('fukced.csv', low_memory=False)
datasetx.info()

# %%
datasetx.fillna(0,inplace=True)

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split=StratifiedShuffleSplit(n_splits=1, test_size=0.2,random_state=42)
for train_index, test_index in split.split(datasetx, datasetx["CANCELLED"]):
    strat_train_set=datasetx.loc[train_index]
    strat_test_set= datasetx.loc[test_index]

# %%
xtrain= strat_train_set.drop("CANCELLED",axis=1)
ytrain= strat_train_set["CANCELLED"].copy()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-44-76a493eb6942> in <module>
# ----> 1 xtrain= strat_train_set.drop("CANCELLED",axis=1)
#       2 ytrain= strat_train_set["CANCELLED"].copy()
#       3
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()
model.fit(xtrain, ytrain)

# %%
# from sklearn.model_selection import StratifiedShuffleSplit
# split=StratifiedShuffleSplit(n_splits=1, test_size=0.2,random_state=42)
# for train_index, test_index in split.split(datasetx, datasetx["CANCELLED"]):
#     strat_train_set=datasetx.loc[train_index]
#     strat_test_set= datasetx.loc[test_index]
    
# xtrain= strat_train_set.drop("CANCELLED",axis=1)
# ytrain= strat_train_set["CANCELLED"].copy()

# from sklearn.neural_network import MLPClassifier
# mlp= MLPClassifier(hidden_layer_sizes=(25,10))
# pred= mlp.fit(xtrain, ytrain)
