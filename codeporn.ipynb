# %%
import pandas as pd

dataset = pd.read_csv(r"C:\Users\user\Desktop\project\Flight-Delay-master\Flight-Delay-master\test 101\final11.csv", 
                          index_col=False,low_memory=False)
                          #names=["month","station_name","day","max_temp","min_temp","avg_temp","dep_temp","ADP_temp","AWB_temp","degree_days_heat","degree_days_cool","weather_type","snow_depth","space","snow_fall","TLC_precipitation","pressure_avg_stn","pressure_avg_SL","?1","?2","wind","peak_speed","peak_dir","sust_speed","sust_dir"])
                          #columns=["month","station_name","day","max_temp","min_temp","avg_temp","dep_temp","ADP_temp","AWB_temp","degree_days_heat","degree_days_cool","weather_type","snow_depth","space","snow_fall","TLC_precipitation","pressure_avg_stn","pressure_avg_SL","?1","?2","wind","peak_speed","peak_dir","sust_speed","sust_dir"])

# dataset = dataset_jan
# dataset.append(dataset_feb)
# dataset.append(dataset_mar)
# dataset.append(dataset_apr)
# dataset.append(dataset_may)
# dataset.append(dataset_jun)
# dataset.append(dataset_jul)
# dataset.append(dataset_aug)
# dataset.append(dataset_sep)
# dataset.append(dataset_oct)
# dataset.append(dataset_nov)
# dataset.append(dataset_dec)
dataset.sample(5)
# Out:
#        id month       station_name day max_temp min_temp avg_temp dep_temp  \
# 86624   1    11      WILMINGTON NC   6       82       61       72       13
# 189523  1    11  WALLOPS ISLAND VA  23       42       28       35      -12
# 100530  1     1     SCOTTSBLUFF NE   7       10      -14       -2      -29
# 53753   1     7         LUBBOCK TX  27       96       73       85        5
# 11888   1     2      HUNTINGTON WV  10       53       19       36        1
#
#        ADP_temp AWB_temp  ... pressure_avg_stn pressure_avg_SL   ?1  ?2 wind  \
# 86624        64       65  ...            30.03           30.06  0.9  27  2.7
# 189523       26       32  ...            30.08           30.12  3.2  33  3.5
# 100530       -6        0  ...            26.21           30.58  4.5  11  7.5
# 53753        56       67  ...            26.71              30  7.5  18  7.9
# 11888        14       28  ...            29.33           30.21  5.2  19  5.8
#
# ...

# %%
data_st = pd.read_csv(r"C:\Users\user\Desktop\project\Flight-Delay-master\Flight-Delay-master\test102\Station List.txt", header=None, sep = "|")

# %%
data_st=data_st.sort_values([2],ascending=True)

# %%
data_st.sample(5)
# Out:
#         0      1                                    2              3   4
# 78   EKO   24121                    Elko Rgnl Airport           Elko  NV
# 212  SFO   23234  San Francisco International Airport  San Francisco  CA
# 90   FSM   13964                Ft Smith Rgnl Airport            NaN  AR
# 126  ADQ   25501                       Kodiak Airport         Kodiak  AK
# 91   FWA   14827       Ft Wayne International Airport            NaN  IN

# %%
data_st_arr = data_st[0].unique()

# %%
station_weather_list = pd.read_csv(r"C:\Users\user\Desktop\project\Flight-Delay-master\Flight-Delay-master\test102\station weather.csv")

# %%
#Flight data

flight_data = pd.read_csv(r"C:\Users\user\Desktop\project\Flight-Delay-master\Flight-Delay-master\flights_new\dataset.csv")

# %%
flight_data = flight_data.drop(['YEAR',
                      'FL_DATE',
                      'OP_CARRIER_AIRLINE_ID',
                      'OP_CARRIER','TAIL_NUM',
                      'OP_CARRIER_FL_NUM',
                      'ORIGIN_AIRPORT_SEQ_ID',
                      'ORIGIN_CITY_MARKET_ID',
                      'ORIGIN_CITY_NAME',
                      'ORIGIN_STATE_ABR',
                      'ORIGIN_STATE_FIPS',
                      'ORIGIN_STATE_NM',
                      'ORIGIN_WAC',
                      'DEST_AIRPORT_SEQ_ID',
                      'DEST_AIRPORT_SEQ_ID',
                      'DEST_CITY_NAME',
                      'DEST_STATE_ABR',
                      'DEST_STATE_FIPS',
                      'DEST_STATE_NM',
                      'DEST_WAC',
                      'DEP_TIME',
                      'DEP_DELAY',
                      'TAXI_OUT',
                      'WHEELS_OFF',
                      'WHEELS_ON',
                      'TAXI_IN',
                      'ARR_TIME',
                      'ARR_DELAY',
                      'ACTUAL_ELAPSED_TIME',
                      'AIR_TIME',
                      'FLIGHTS',
                      'DIVERTED',
                      'DISTANCE_GROUP',
                      'DIV_AIRPORT_LANDINGS'
                     ], axis=1)

flight_data.head()
# Out:
#    QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  \
# 0        2      6             2            3                AA
# 1        2      6             3            4                AA
# 2        2      6             4            5                AA
# 3        2      6             5            6                AA
# 4        2      6             7            1                AA
#
#    ORIGIN_AIRPORT_ID ORIGIN  DEST_AIRPORT_ID  DEST_CITY_MARKET_ID DEST  ...  \
# 0              11057    CLT            13198                33198  MCI  ...
# 1              12953    LGA            13303                32467  MIA  ...
# 2              12953    LGA            13303                32467  MIA  ...
# 3              12953    LGA            13303                32467  MIA  ...
# 4              12953    LGA            13303                32467  MIA  ...
#
#    DEP_DELAY_GROUP  DEP_TIME_BLK  CRS_ARR_TIME  ARR_DELAY_NEW ARR_DEL15  \
# ...

# %%
flight_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2157737 entries, 0 to 2157736
# Data columns (total 23 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   QUARTER              int64
#  1   MONTH                int64
#  2   DAY_OF_MONTH         int64
#  3   DAY_OF_WEEK          int64
#  4   OP_UNIQUE_CARRIER    object
#  5   ORIGIN_AIRPORT_ID    int64
#  6   ORIGIN               object
#  7   DEST_AIRPORT_ID      int64
#  8   DEST_CITY_MARKET_ID  int64
#  9   DEST                 object
#  10  CRS_DEP_TIME         int64
#  11  DEP_DELAY_NEW        float64
#  12  DEP_DEL15            float64
#  13  DEP_DELAY_GROUP      float64
#  14  DEP_TIME_BLK         object
#  15  CRS_ARR_TIME         int64
#  16  ARR_DELAY_NEW        float64
#  17  ARR_DEL15            float64
#  18  ARR_DELAY_GROUP      float64
#  19  ARR_TIME_BLK         object
#  20  CANCELLED            float64
#  21  CRS_ELAPSED_TIME     float64
#  22  DISTANCE             float64
# ...

# %%
flight_data_jan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450017 entries, 0 to 450016
# Data columns (total 17 columns):
# MONTH                  450017 non-null int64
# DAY_OF_MONTH           450017 non-null int64
# DAY_OF_WEEK            450017 non-null int64
# OP_UNIQUE_CARRIER      450017 non-null object
# ORIGIN_AIRPORT_ID      450017 non-null int64
# ORIGIN                 450017 non-null object
# DEST_AIRPORT_ID        450017 non-null int64
# DEST_CITY_MARKET_ID    450017 non-null int64
# DEST                   450017 non-null object
# CRS_DEP_TIME           450017 non-null int64
# DEP_DELAY_NEW          441476 non-null float64
# CRS_ARR_TIME           450017 non-null int64
# ARR_DELAY_NEW          439645 non-null float64
# CANCELLED              450017 non-null float64
# CANCELLATION_CODE      8886 non-null object
# CRS_ELAPSED_TIME       450013 non-null float64
# DISTANCE               450017 non-null float64
# dtypes: float64(5), int64(8), object(4)
# memory usage: 58.4+ MB

# %%
#origin
station_weather_list_orig = station_weather_list.rename(columns={'station_code': 'ORIGIN', 'month': 'MONTH', 'day': 'DAY_OF_MONTH', #keys
                                                            
'id' : 'Origin_id',

'station_name' : 'Origin_station_name',

'max_temp' : 'Origin_max_temp',
'min_temp' : 'Origin_min_temp',
'avg_temp' : 'Origin_avg_temp',
'dep_temp' : 'Origin_dep_temp',
'ADP_temp' : 'Origin_ADP_temp',
'AWB_temp' : 'Origin_AWB_temp',
'degree_days_heat' : 'Origin_degree_days_heat',
'degree_days_cool' : 'Origin_degree_days_cool',
'weather_type' : 'Origin_weather_type',
'snow_depth' : 'Origin_snow_depth',
'space' : 'Origin_space',
'snow_fall' : 'Origin_snow_fall',
'TLC_precipitation' : 'Origin_TLC_precipitation',
'pressure_avg_stn' : 'Origin_pressure_avg_stn',
'pressure_avg_SL' : 'Origin_pressure_avg_SL',
'?1' : 'Origin_?1',
'?2' : 'Origin_?2',
'wind' : 'Origin_wind',
'peak_speed' : 'Origin_peak_speed',
'peak_dir' : 'Origin_peak_dir',
'sust_speed' : 'Origin_sust_speed',
'sust_dir' : 'Origin_sust_dir'})

# %%
#Destination
station_weather_list_dest = station_weather_list.rename(columns={'station_code': 'DEST', 'month': 'MONTH', 'day': 'DAY_OF_MONTH', #keys
                                                            
'id' : 'Dest_id',
'max_temp' : 'Dest_max_temp',
'min_temp' : 'Dest_min_temp',
'avg_temp' : 'Dest_avg_temp',
'dep_temp' : 'Dest_dep_temp',
'ADP_temp' : 'Dest_ADP_temp',
'AWB_temp' : 'Dest_AWB_temp',
'degree_days_heat' : 'Dest_degree_days_heat',
'degree_days_cool' : 'Dest_degree_days_cool',
'weather_type' : 'Dest_weather_type',
'snow_depth' : 'Dest_snow_depth',
'space' : 'Dest_space',
'snow_fall' : 'Dest_snow_fall',
'TLC_precipitation' : 'Dest_TLC_precipitation',
'pressure_avg_stn' : 'Dest_pressure_avg_stn',
'pressure_avg_SL' : 'Dest_pressure_avg_SL',
'?1' : 'Dest_?1',
'?2' : 'Dest_?2',
'wind' : 'Dest_wind',
'peak_speed' : 'Dest_peak_speed',
'peak_dir' : 'Dest_peak_dir',
'sust_speed' : 'Dest_sust_speed',
'sust_dir' : 'Dest_sust_dir'})

# %%
station_weather_list_orig['ORIGIN'] = station_weather_list_orig['ORIGIN'].str.strip()
station_weather_list_orig.head()
# Out:
#   ORIGIN  Origin_id  MONTH Origin_station_name  DAY_OF_MONTH  Origin_max_temp  \
# 0   NSTU          1      1        PAGO PAGO AQ             1               89
# 1   NSTU          1      1        PAGO PAGO AQ             2               88
# 2   NSTU          1      1        PAGO PAGO AQ             3               89
# 3   NSTU          1      1        PAGO PAGO AQ             4               88
# 4   NSTU          1      1        PAGO PAGO AQ             5               89
#
#    Origin_min_temp  Origin_avg_temp  Origin_dep_temp  Origin_ADP_temp  ...  \
# 0               82               86                4             79.0  ...
# 1               80               84                2             79.0  ...
# 2               80               85                3             79.0  ...
# 3               80               84                2             79.0  ...
# 4               79               84                2             79.0  ...
#
# ...

# %%
combined_data = pd.merge(flight_data, station_weather_list_orig, on=['MONTH', 'DAY_OF_MONTH', 'ORIGIN'], how='inner')
combined_data.head()
# Out:
#    QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  \
# 0        2      6             2            3                AA
# 1        2      6             2            3                AA
# 2        2      6             2            3                AA
# 3        2      6             2            3                AA
# 4        2      6             2            3                AA
#
#    ORIGIN_AIRPORT_ID ORIGIN  DEST_AIRPORT_ID  DEST_CITY_MARKET_ID DEST  ...  \
# 0              11057    CLT            13198                33198  MCI  ...
# 1              11057    CLT            14107                30466  PHX  ...
# 2              11057    CLT            10994                30994  CHS  ...
# 3              11057    CLT            14100                34100  PHL  ...
# 4              11057    CLT            13204                31454  MCO  ...
#
#    Origin_pressure_avg_stn  Origin_pressure_avg_SL  Origin_?1  Origin_?2  \
# ...

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1926150 entries, 0 to 1926149
# Data columns (total 48 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   QUARTER                   int64
#  1   MONTH                     int64
#  2   DAY_OF_MONTH              int64
#  3   DAY_OF_WEEK               int64
#  4   OP_UNIQUE_CARRIER         object
#  5   ORIGIN_AIRPORT_ID         int64
#  6   ORIGIN                    object
#  7   DEST_AIRPORT_ID           int64
#  8   DEST_CITY_MARKET_ID       int64
#  9   DEST                      object
#  10  CRS_DEP_TIME              int64
#  11  DEP_DELAY_NEW             float64
#  12  DEP_DEL15                 float64
#  13  DEP_DELAY_GROUP           float64
#  14  DEP_TIME_BLK              object
#  15  CRS_ARR_TIME              int64
#  16  ARR_DELAY_NEW             float64
#  17  ARR_DEL15                 float64
#  18  ARR_DELAY_GROUP           float64
#  19  ARR_TIME_BLK              object
# ...

# %%
station_weather_list_dest['DEST'] = station_weather_list_dest['DEST'].str.strip()
station_weather_list_dest.head()
# Out:
#    DEST  Dest_id  MONTH  station_name  DAY_OF_MONTH  Dest_max_temp  \
# 0  NSTU        1      1  PAGO PAGO AQ             1             89
# 1  NSTU        1      1  PAGO PAGO AQ             2             88
# 2  NSTU        1      1  PAGO PAGO AQ             3             89
# 3  NSTU        1      1  PAGO PAGO AQ             4             88
# 4  NSTU        1      1  PAGO PAGO AQ             5             89
#
#    Dest_min_temp  Dest_avg_temp  Dest_dep_temp  Dest_ADP_temp  ...  \
# 0             82             86              4           79.0  ...
# 1             80             84              2           79.0  ...
# 2             80             85              3           79.0  ...
# 3             80             84              2           79.0  ...
# 4             79             84              2           79.0  ...
#
#    Dest_pressure_avg_stn  Dest_pressure_avg_SL  Dest_?1 Dest_?2  Dest_wind  \
# 0                  29.80                 29.81      7.5    10.0        9.0
# ...

# %%
combined_data_2 = pd.merge(flight_data, station_weather_list_dest,on=['DEST', 'MONTH', 'DAY_OF_MONTH'], how='inner')
combined_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1926238 entries, 0 to 1926237
# Data columns (total 48 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   QUARTER                 int64
#  1   MONTH                   int64
#  2   DAY_OF_MONTH            int64
#  3   DAY_OF_WEEK             int64
#  4   OP_UNIQUE_CARRIER       object
#  5   ORIGIN_AIRPORT_ID       int64
#  6   ORIGIN                  object
#  7   DEST_AIRPORT_ID         int64
#  8   DEST_CITY_MARKET_ID     int64
#  9   DEST                    object
#  10  CRS_DEP_TIME            int64
#  11  DEP_DELAY_NEW           float64
#  12  DEP_DEL15               float64
#  13  DEP_DELAY_GROUP         float64
#  14  DEP_TIME_BLK            object
#  15  CRS_ARR_TIME            int64
#  16  ARR_DELAY_NEW           float64
#  17  ARR_DEL15               float64
#  18  ARR_DELAY_GROUP         float64
#  19  ARR_TIME_BLK            object
#  20  CANCELLED               float64
# ...

# %%
combined_data_final = pd.merge(combined_data, combined_data_2,on=None, how='inner')
combined_data_final.head()
# Out:
#    QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  \
# 0        2      6             2            3                AA
# 1        2      6             2            3                AA
# 2        2      6             2            3                AA
# 3        2      6             2            3                AA
# 4        2      6             2            3                AA
#
#    ORIGIN_AIRPORT_ID ORIGIN  DEST_AIRPORT_ID  DEST_CITY_MARKET_ID DEST  ...  \
# 0              11057    CLT            13198                33198  MCI  ...
# 1              11057    CLT            14107                30466  PHX  ...
# 2              11057    CLT            10994                30994  CHS  ...
# 3              11057    CLT            14100                34100  PHL  ...
# 4              11057    CLT            13204                31454  MCO  ...
#
#    Dest_TLC_precipitation  Dest_pressure_avg_stn  Dest_pressure_avg_SL  \
# ...

# %%
combined_data_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1727654 entries, 0 to 1727653
# Data columns (total 72 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   QUARTER                   int64
#  1   MONTH                     int64
#  2   DAY_OF_MONTH              int64
#  3   DAY_OF_WEEK               int64
#  4   OP_UNIQUE_CARRIER         object
#  5   ORIGIN_AIRPORT_ID         int64
#  6   ORIGIN                    object
#  7   DEST_AIRPORT_ID           int64
#  8   DEST_CITY_MARKET_ID       int64
#  9   DEST                      object
#  10  CRS_DEP_TIME              int64
#  11  DEP_DELAY_NEW             float64
#  12  DEP_DEL15                 float64
#  13  DEP_DELAY_GROUP           float64
#  14  DEP_TIME_BLK              object
#  15  CRS_ARR_TIME              int64
#  16  ARR_DELAY_NEW             float64
#  17  ARR_DEL15                 float64
#  18  ARR_DELAY_GROUP           float64
#  19  ARR_TIME_BLK              object
# ...

# %%
combined_data_final.sample(5)
# Out:
#          QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  \
# 1426688        1      3            16            3                F9
# 147803         2      6            19            6                DL
# 1161582        4     12            28            2                DL
# 495703         3      9            19            7                YV
# 1414616        1      3            11            5                WN
#
#          ORIGIN_AIRPORT_ID ORIGIN  DEST_AIRPORT_ID  DEST_CITY_MARKET_ID DEST  \
# 1426688              10821    BWI            13204                31454  MCO
# 147803               10397    ATL            13871                33316  OMA
# 1161582              12478    JFK            10397                30397  ATL
# 495703               11540    ELP            11298                30194  DFW
# 1414616              14576    ROC            13204                31454  MCO
#
#          ...  Dest_TLC_precipitation  Dest_pressure_avg_stn  \
# ...

# %%
combined_data_final.to_csv('combined.csv')
combined_data_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1727654 entries, 0 to 1727653
# Data columns (total 72 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   QUARTER                   int64
#  1   MONTH                     int64
#  2   DAY_OF_MONTH              int64
#  3   DAY_OF_WEEK               int64
#  4   OP_UNIQUE_CARRIER         object
#  5   ORIGIN_AIRPORT_ID         int64
#  6   ORIGIN                    object
#  7   DEST_AIRPORT_ID           int64
#  8   DEST_CITY_MARKET_ID       int64
#  9   DEST                      object
#  10  CRS_DEP_TIME              int64
#  11  DEP_DELAY_NEW             float64
#  12  DEP_DEL15                 float64
#  13  DEP_DELAY_GROUP           float64
#  14  DEP_TIME_BLK              object
#  15  CRS_ARR_TIME              int64
#  16  ARR_DELAY_NEW             float64
#  17  ARR_DEL15                 float64
#  18  ARR_DELAY_GROUP           float64
#  19  ARR_TIME_BLK              object
# ...

# %%
#Flight data


flight_data = pd.read_csv("Flight-data\Data\data.csv", low_memory = False)

# %%
flight_data = flight_data.drop(['YEAR',
                      'FL_DATE',
                      'OP_CARRIER_AIRLINE_ID',
                      'OP_CARRIER','TAIL_NUM',
                      'OP_CARRIER_FL_NUM',
                      'ORIGIN_AIRPORT_SEQ_ID',
                      'ORIGIN_CITY_MARKET_ID',
                      'ORIGIN_CITY_NAME',
                      'ORIGIN_STATE_ABR',
                      'ORIGIN_STATE_FIPS',
                      'ORIGIN_STATE_NM',
                      'ORIGIN_WAC',
                      'DEST_AIRPORT_SEQ_ID',
                      'DEST_AIRPORT_SEQ_ID',
                      'DEST_CITY_NAME',
                      'DEST_STATE_ABR',
                      'DEST_STATE_FIPS',
                      'DEST_STATE_NM',
                      'DEST_WAC',
                      'DEP_TIME',
                      'DEP_DELAY',
                      'TAXI_OUT',
                      'WHEELS_OFF',
                      'WHEELS_ON',
                      'TAXI_IN',
                      'ARR_TIME',
                      'ARR_DELAY',
                      'ACTUAL_ELAPSED_TIME',
                      'AIR_TIME',
                      'FLIGHTS',
                      'CARRIER_DELAY',
                      'WEATHER_DELAY',
                      'NAS_DELAY',
                      'SECURITY_DELAY',
                      'LATE_AIRCRAFT_DELAY',
                      'FIRST_DEP_TIME',
                      'TOTAL_ADD_GTIME',
                      'LONGEST_ADD_GTIME',
                      'Unnamed: 55',
                     ], axis=1)

# %%
#For the entire dataset

#flight_data = flight_data.drop(["FIRST_DEP_TIME","TOTAL_ADD_GTIME","LONGEST_ADD_GTIME","Unnamed: 55"],axis=1)

#origin
station_weather_list_orig = station_weather_list.rename(columns={'station_code': 'ORIGIN', 'month': 'MONTH', 'day': 'DAY_OF_MONTH', #keys
                                                            
'id' : 'Origin_id',

'station_name' : 'Origin_station_name',

'max_temp' : 'Origin_max_temp',
'min_temp' : 'Origin_min_temp',
'avg_temp' : 'Origin_avg_temp',
'dep_temp' : 'Origin_dep_temp',
'ADP_temp' : 'Origin_ADP_temp',
'AWB_temp' : 'Origin_AWB_temp',
'degree_days_heat' : 'Origin_degree_days_heat',
'degree_days_cool' : 'Origin_degree_days_cool',
'weather_type' : 'Origin_weather_type',
'snow_depth' : 'Origin_snow_depth',
'space' : 'Origin_space',
'snow_fall' : 'Origin_snow_fall',
'TLC_precipitation' : 'Origin_TLC_precipitation',
'pressure_avg_stn' : 'Origin_pressure_avg_stn',
'pressure_avg_SL' : 'Origin_pressure_avg_SL',
'?1' : 'Origin_?1',
'?2' : 'Origin_?2',
'wind' : 'Origin_wind',
'peak_speed' : 'Origin_peak_speed',
'peak_dir' : 'Origin_peak_dir',
'sust_speed' : 'Origin_sust_speed',
'sust_dir' : 'Origin_sust_dir'})

#Destination
station_weather_list_dest = station_weather_list.rename(columns={'station_code': 'DEST', 'month': 'MONTH', 'day': 'DAY_OF_MONTH', #keys
                                                            
'id' : 'Dest_id',
'max_temp' : 'Dest_max_temp',
'min_temp' : 'Dest_min_temp',
'avg_temp' : 'Dest_avg_temp',
'dep_temp' : 'Dest_dep_temp',
'ADP_temp' : 'Dest_ADP_temp',
'AWB_temp' : 'Dest_AWB_temp',
'degree_days_heat' : 'Dest_degree_days_heat',
'degree_days_cool' : 'Dest_degree_days_cool',
'weather_type' : 'Dest_weather_type',
'snow_depth' : 'Dest_snow_depth',
'space' : 'Dest_space',
'snow_fall' : 'Dest_snow_fall',
'TLC_precipitation' : 'Dest_TLC_precipitation',
'pressure_avg_stn' : 'Dest_pressure_avg_stn',
'pressure_avg_SL' : 'Dest_pressure_avg_SL',
'?1' : 'Dest_?1',
'?2' : 'Dest_?2',
'wind' : 'Dest_wind',
'peak_speed' : 'Dest_peak_speed',
'peak_dir' : 'Dest_peak_dir',
'sust_speed' : 'Dest_sust_speed',
'sust_dir' : 'Dest_sust_dir'})



#combined_data_final.info()

# %%
combined_data = pd.merge(flight_data, station_weather_list_orig, on=['MONTH', 'DAY_OF_MONTH', 'ORIGIN'], how='inner')
combined_data.sample(5)
# Out:
#          MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  \
# 444503       8            13            7                OO
# 1535885      2             2            4                DL
# 3907470      5            18            4                OO
# 987240      12            17            7                WN
# 3596257      5            24            3                UA
#
#          ORIGIN_AIRPORT_ID ORIGIN  DEST_AIRPORT_ID  DEST_CITY_MARKET_ID DEST  \
# 444503               14869    SLC            11097                31097  COD
# 1535885              10397    ATL            13851                33851  OKC
# 3907470              10874    CAK            11433                31295  DTW
# 987240               11278    DCA            13342                33342  MKE
# 3596257              13204    MCO            14771                32457  SFO
#
#          CRS_DEP_TIME     ...       Origin_pressure_avg_stn  \
# 444503           1100     ...                         25.61
# ...

# %%
combined_data_2 = pd.merge(flight_data, station_weather_list_dest,on=['DEST', 'MONTH', 'DAY_OF_MONTH'], how='inner')
combined_data_2.sample(5)
# Out:
#          MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  \
# 4983284      9            13            3                DL
# 880953       8            10            4                OO
# 4066552     11             1            3                WN
# 3894939      5             1            1                F9
# 2734097      6             7            3                AA
#
#          ORIGIN_AIRPORT_ID ORIGIN  DEST_AIRPORT_ID  DEST_CITY_MARKET_ID DEST  \
# 4983284              14747    SEA            10693                30693  BNA
# 880953               13930    ORD            13485                33485  MSN
# 4066552              12451    JAX            10821                30852  BWI
# 3894939              11193    CVG            11298                30194  DFW
# 2734097              11057    CLT            11278                30852  DCA
#
#          CRS_DEP_TIME     ...       Dest_pressure_avg_stn  \
# 4983284          1715     ...                       29.18
# ...

# %%
combined_data_final = pd.merge(combined_data, combined_data_2,on=None, how='inner')
combined_data_final.sample(5)

# %%
combined_data_final.to_csv('combined.csv')
combined_data_final.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c9a2472c87e6> in <module>
# ----> 1 combined_data_final.to_csv('combined.csv')
#       2 combined_data_final.info()
#
# NameError: name 'combined_data_final' is not defined
